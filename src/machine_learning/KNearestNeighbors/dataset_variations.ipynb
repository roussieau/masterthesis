# %% [markdown]
# # Dataset variations

# %%
# %load_ext autoreload
# %autoreload

# Imports
import pandas as pd
from sklearn.preprocessing import Normalizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split


import sys

from KNeighbors import display_plot
sys.path.append('../utils')
from utils import perf, thomas_parser

# %% [markdown]
# ### Comparison between different kind of datasets

# %%
perf('../../dumps/dataset_variations/16K-19-05-T3.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.983
# Accuracy on test set: 0.981

# %% [markdown]
# #### Different thresholds

# %%
perf('../../dumps/dataset_variations/16K-19-05-T1.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.957
# Accuracy on test set: 0.956

# %%
perf('../../dumps/dataset_variations/16K-19-05-T2.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.975
# Accuracy on test set: 0.972

# %%
perf('../../dumps/dataset_variations/16K-19-05-T4.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.991
# Accuracy on test set: 0.987

# %%
perf('../../dumps/16K-19-05-T5.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.991
# Accuracy on test set: 0.988

# %% [markdown]
# #### Errors considered as positive result from detector

# %%
perf('../../dumps/dataset_variations/16K-22-05-error.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.983
# Accuracy on test set: 0.982

# %% [markdown]
# #### Check influence of each detector

# %%
perf('../../dumps/dataset_variations/16K-22-05-DIE.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.984
# Accuracy on test set: 0.979

# %%
perf('../../dumps/dataset_variations/16K-22-05-CISCO.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.990
# Accuracy on test set: 0.987

# %%
perf('../../dumps/dataset_variations/16K-22-05-MANALYZE.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.983
# Accuracy on test set: 0.982

# %%
perf('../../dumps/dataset_variations/16K-22-05-PEID.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.991
# Accuracy on test set: 0.990

# %%
perf('../../dumps/dataset_variations/16K-22-05-PEFRAME.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.991
# Accuracy on test set: 0.988

# %% [markdown]
# #### Only boolean values

# %%
perf('../../dumps/dataset_variations/16K-19-05-T3.csv','neigh',True)
# Out:
# Most important :
#
# Accuracy on training set: 0.988
# Accuracy on test set: 0.989
# ---------------
#
# All features :
#
# Accuracy on training set: 0.994
# Accuracy on test set: 0.993

# %% [markdown]
# #### Agreement on same packer

# %%
perf('../../dumps/dataset_variations/16K-22-05-agreement.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.983
# Accuracy on test set: 0.983

# %% [markdown]
# #### Test with Thomas datasets

# %%
parsed_csv = thomas_parser("../../dumps/thomas_datasets/2019-08.Merged")
gt = pd.read_csv(parsed_csv)
display_plot(parsed_csv,0.20,15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a4abfdc0fc27> in <module>
# ----> 1 parsed_csv = thomas_parser("../../dumps/thomas_datasets/2019-08.Merged")
#       2 gt = pd.read_csv(parsed_csv)
#       3 display_plot(parsed_csv,0.20,15)
#
# ~/Documents/UCL/Memoire/masterthesis/src/machine_learning/utils/utils.py in thomas_parser(csv_path)
#     385 	df1 = pd.DataFrame(data=data[0:,0:],
#     386                             index=[i for i in range(data.shape[0])],
# --> 387 	                    columns=['f'+str(i+1) for i in range(1, data_train.shape[1]+1)])
#     388         target = np.array(target_filter)
#     389         df2 = pd.DataFrame({'label':target})
#
# NameError: name 'data_train' is not defined

# %%
parsed_csv = thomas_parser("../../dumps/thomas_datasets/2019-09.Merged")
gt = pd.read_csv(parsed_csv)
display_plot(parsed_csv,0.20,10)
