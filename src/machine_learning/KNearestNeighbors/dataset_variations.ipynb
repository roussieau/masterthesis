# %% [markdown]
# # Dataset variations

# %%
# Imports
import pandas as pd
from sklearn.preprocessing import Normalizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split


import sys

from KNeighbors import display_plot
sys.path.append('../utils')
from utils import perf, thomas_parser

# %% [markdown]
# ### Comparison between different kind of datasets

# %%
perf('../../dumps/control_8000_false_3.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.979
# Accuracy on test set: 0.977

# %% [markdown]
# #### Different thresholds

# %%
perf('../../dumps/default_1.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.951
# Accuracy on test set: 0.940

# %%
perf('../../dumps/default_2.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.969
# Accuracy on test set: 0.961

# %%
perf('../../dumps/default_4.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.984
# Accuracy on test set: 0.977

# %%
perf('../../dumps/default_5.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.984
# Accuracy on test set: 0.977

# %% [markdown]
# #### Errors considered as positive result from detector

# %%
perf('../../dumps/error_as_packed.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.968
# Accuracy on test set: 0.961

# %% [markdown]
# #### Check influence of each detector

# %%
perf('../../dumps/not_die.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.981
# Accuracy on test set: 0.977

# %%
perf('../../dumps/not_cisco.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.982
# Accuracy on test set: 0.977

# %%
perf('../../dumps/not_manalyze.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.982
# Accuracy on test set: 0.976

# %%
perf('../../dumps/not_peid.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.983
# Accuracy on test set: 0.977

# %%
perf('../../dumps/not_peframe.csv','neigh',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.984
# Accuracy on test set: 0.978

# %% [markdown]
# #### Only boolean values

# %%
perf('../../dumps/control_8000_false_3.csv','neigh',True)
# Out:
# Most important :
#
# Accuracy on training set: 0.989
# Accuracy on test set: 0.988
# ---------------
#
# All features :
#
# Accuracy on training set: 0.994
# Accuracy on test set: 0.991

# %% [markdown]
# #### Test with Thomas datasets

# %%
parsed_csv = thomas_parser("../../dumps/2019-08.Merged")
gt = pd.read_csv(parsed_csv)
display_plot(parsed_csv,0.20,15)

# %%
parsed_csv = thomas_parser("../../dumps/2019-09.Merged")
gt = pd.read_csv(parsed_csv)
display_plot(parsed_csv,0.20,10)
