# %% [markdown]
# # Principal Component Analysis

# %%
# Imports
import sys
sys.path.append('../../utils')
from utils import PCA_reduction, PCA_components, PCA_snapshot

# %%
PCA_reduction('../../../dumps/various_sizes/16K.csv','gradient')
# Out:
# Variance      Training acc    Test acc  Components      Time (s)
# ----------  --------------  ----------  ------------  ----------
# no pca            0.991815    0.987843  all              1.86144
# 1                 0.990568    0.983791  119              7.53695
# 0.99              0.990412    0.982232  102              6.16705
# 0.95              0.990022    0.981608  82               4.62079
# 0.9               0.99049     0.983167  64               3.78028
# 0.85              0.990022    0.982544  52               2.88024

# %%
PCA_components('../../../dumps/various_sizes/16K.csv','gradient')
# Out:
# Top 5 combinations of features :
#
# # components      Test accuracy    Time (s)    Fixed cost (s)
# --------------  ---------------  ----------  ----------------
# no PCA                 0.995012     5.93389
# 33                     0.990648     5.78071         0.113468
# 25                     0.990025     4.38306         0.096674
# 28                     0.989713     4.90099         0.105229
# 23                     0.989401     4.00748         0.0894471
# 29                     0.989401     5.06027         0.103522
# 33

# %%
PCA_snapshot('../../../dumps/time_analysis/threshold_3/3_20190615_31000.csv','gradient','../../')
# Out:
# Top 5 features combinations with times <= than default case :
#
# # components         Acc     Time
# --------------  --------  -------
# no PCA          0.982742  9.31982
# 13              0.980161  5.84374
# 8               0.979355  3.99961
# 14              0.979355  5.69437
# 15              0.978387  6.25754
# 18              0.978387  8.03083
# Accuracy on training set: 0.958
# Accuracy on test set: 0.896
