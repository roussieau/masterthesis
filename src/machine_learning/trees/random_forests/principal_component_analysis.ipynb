# %% [markdown]
# # Principal Component Analysis

# %%
# Imports
import sys
sys.path.append('../../utils')
from utils import PCA_reduction, PCA_components, PCA_snapshot

# %%
PCA_reduction('../../../dumps/various_sizes/16K.csv','forest')
# Out:
# Variance      Training acc    Test acc  Components      Time (s)
# ----------  --------------  ----------  ------------  ----------
# no pca            0.988463    0.987843  all             0.125083
# 1                 0.97903     0.973504  119             0.580527
# 0.99              0.981681    0.977868  102             0.5587
# 0.95              0.978407    0.974439  82              0.529512
# 0.9               0.972404    0.966646  64              0.489388
# 0.85              0.973418    0.968516  52              0.454956

# %% [markdown]
# We can save 20% of computation time while keeping 52 aggregated features for a loss of 0.5% in precision.

# %%
PCA_components('../../../dumps/various_sizes/16K.csv','forest')
# Out:
# Top 5 combinations of features :
#
# # components      Test accuracy    Time (s)    Fixed cost (s)
# --------------  ---------------  ----------  ----------------
# no PCA                 0.989713    0.42876
# 7                      0.973815    0.338177         0.0789557
# 6                      0.97101     0.338584         0.0705373
# 5                      0.970075    0.334338         0.0781084
# 4                      0.969763    0.319544         0.0780583
# 8                      0.969763    0.338273         0.0822626
# 7

# %%
PCA_snapshot('../../../dumps/time_analysis/threshold_3/3_20190615_31000.csv','forest','../../')
# Out:
# Top 5 features combinations with times <= than default case :
#
# # components         Acc      Time
# --------------  --------  --------
# no PCA          0.982419  0.737331
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-3fc974729087> in <module>
# ----> 1 PCA_snapshot('../../../dumps/time_analysis/threshold_3/3_20190615_31000.csv','forest','../../')
#
# ~/code/src/machine_learning/utils/utils.py in PCA_snapshot(csv, kind, path_to_parent)
#     327
#     328         clf = algo_picker(kind)
# --> 329         pca = PCA(n_components=PCA_components(csv, kind, False))
#     330
#     331         pca.fit(data_train)
#
# ~/code/src/machine_learning/utils/utils.py in PCA_components(csv, kind, silent)
#     318                 print(tabulate(filtered_cell, headers = ['# components','Acc','Time']))
#     319
# --> 320         return filtered_cell[1][0]
#     321
# ...
