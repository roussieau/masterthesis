# %% [markdown]
# # Dataset variations

# %%
# Imports
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

import sys
sys.path.append("../../utils")
from utils import perf, thomas_parser

# %%
perf('../../../dumps/dataset_variations/16K-19-05-T3.csv','forest',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.995
# Accuracy on test set: 0.994

# %% [markdown]
# ## Different thresholds

# %%
perf('../../../dumps/dataset_variations/16K-19-05-T1.csv','forest',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.964
# Accuracy on test set: 0.966

# %%
perf('../../../dumps/dataset_variations/16K-19-05-T2.csv','forest',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.992
# Accuracy on test set: 0.993

# %%
perf('../../../dumps/dataset_variations/16K-19-05-T4.csv','forest',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.998
# Accuracy on test set: 0.998

# %%
perf('../../../dumps/dataset_variations/16K-19-05-T5.csv','forest',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.998
# Accuracy on test set: 0.998

# %% [markdown]
# ## Errors considered as positive result from detector

# %%
perf('../../../dumps/dataset_variations/16K-22-05-error.csv','forest',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.995
# Accuracy on test set: 0.994

# %% [markdown]
# ## Check influence of each detector

# %%
perf('../../../dumps/dataset_variations/16K-22-05-DIE.csv','forest',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.994
# Accuracy on test set: 0.993

# %%
perf('../../../dumps/dataset_variations/16K-22-05-CISCO.csv','forest',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.998
# Accuracy on test set: 0.996

# %%
perf('../../../dumps/dataset_variations/16K-22-05-MANALYZE.csv','forest',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.993
# Accuracy on test set: 0.994

# %%
perf('../../../dumps/dataset_variations/16K-22-05-PEID.csv','forest',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.998
# Accuracy on test set: 0.998

# %%
perf('../../../dumps/dataset_variations/16K-22-05-PEFRAME.csv','forest',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.998
# Accuracy on test set: 0.999

# %% [markdown]
# ## Only boolean values

# %%
perf('../../../dumps/dataset_variations/16K-19-05-T3.csv','forest',True)
# Out:
# Most important :
#
# Accuracy on training set: 0.975
# Accuracy on test set: 0.979
# ---------------
#
# All features :
#
# Accuracy on training set: 0.993
# Accuracy on test set: 0.994

# %% [markdown]
# ## Agreement on same packer

# %%
perf('../../../dumps/dataset_variations/16K-22-05-agreement.csv','forest',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.996
# Accuracy on test set: 0.995

# %% [markdown]
# ## Test with Thomas datasets

# %%
gt = pd.read_csv(thomas_parser("../../../dumps/thomas_datasets/2019-08.Merged"))
cols = [col for col in gt.columns if col not in ['label']]
data = gt[cols]
target = gt['label']

data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.20, random_state = 0)

tree = RandomForestClassifier(n_estimators=10,max_depth=5,min_samples_leaf=9,random_state=0)
tree.fit(data_train, target_train)
print("Accuracy on training set: {:.3f}".format(tree.score(data_train, target_train))) 
print("Accuracy on test set: {:.3f}".format(tree.score(data_test, target_test)))
# Out:
# Accuracy on training set: 0.987
# Accuracy on test set: 0.988

# %%
gt = pd.read_csv(thomas_parser("../../../dumps/thomas_datasets/2019-09.Merged"))
cols = [col for col in gt.columns if col not in ['label']]
data = gt[cols]
target = gt['label']

data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.20, random_state = 0)

tree = RandomForestClassifier(n_estimators=10,max_depth=5,min_samples_leaf=9,random_state=0)
tree.fit(data_train, target_train)
print("Accuracy on training set: {:.3f}".format(tree.score(data_train, target_train))) 
print("Accuracy on test set: {:.3f}".format(tree.score(data_test, target_test)))
# Out:
# Accuracy on training set: 0.985
# Accuracy on test set: 0.981
