# %% [markdown]
# # Dataset variations

# %%
# Imports
import pandas as pd
from sklearn.preprocessing import Normalizer
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split


import sys
sys.path.append('../utils')
from utils import perf, thomas_parser

# %%
perf('../../dumps/dataset_variations/16K-19-05-T3.csv','mlp1',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.999
# Accuracy on test set: 0.996

# %% [markdown]
# #### Different thresholds

# %%
perf('../../dumps/dataset_variations/16K-19-05-T1.csv','mlp1',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.999
# Accuracy on test set: 0.977

# %%
perf('../../dumps/dataset_variations/16K-19-05-T2.csv','mlp1',False)
# Out:
# Most important :
#
# Accuracy on training set: 1.000
# Accuracy on test set: 0.996

# %%
perf('../../dumps/dataset_variations/16K-19-05-T4.csv','mlp1',False)
# Out:
# Most important :
#
# Accuracy on training set: 1.000
# Accuracy on test set: 0.998

# %%
perf('../../dumps/dataset_variations/16K-19-05-T5.csv','mlp1',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.998
# Accuracy on test set: 0.998

# %% [markdown]
# #### Errors considered as positive result from detector

# %%
perf('../../dumps/dataset_variations/16K-22-05-error.csv','mlp1',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.999
# Accuracy on test set: 0.996

# %% [markdown]
# #### Check influence of each detector

# %%
perf('../../dumps/dataset_variations/16K-22-05-DIE.csv','mlp1',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.999
# Accuracy on test set: 0.996

# %%
perf('../../dumps/dataset_variations/16K-22-05-CISCO.csv','mlp1',False)
# Out:
# Most important :
#
# Accuracy on training set: 1.000
# Accuracy on test set: 0.997

# %%
perf('../../dumps/dataset_variations/16K-22-05-MANALYZE.csv','mlp1',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.999
# Accuracy on test set: 0.995

# %%
perf('../../dumps/dataset_variations/16K-22-05-PEID.csv','mlp1',False)
# Out:
# Most important :
#
# Accuracy on training set: 1.000
# Accuracy on test set: 0.999

# %%
perf('../../dumps/dataset_variations/16K-22-05-PEFRAME.csv','mlp1',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.998
# Accuracy on test set: 0.997

# %% [markdown]
# Better results without taking Cisco results into account.

# %% [markdown]
# #### Only boolean values

# %%
perf('../../dumps/dataset_variations/16K-19-05-T3.csv','mlp1',True)
# Out:
# Most important :
#
# Accuracy on training set: 0.993
# Accuracy on test set: 0.989
# ---------------
#
# All features :
#
# Accuracy on training set: 0.999
# Accuracy on test set: 0.996

# %% [markdown]
# Really good performances when using converted values !

# %% [markdown]
# #### Agreement on same packer

# %%
perf('../../dumps/dataset_variations/16K-22-05-agreement.csv','mlp1',False)
# Out:
# Most important :
#
# Accuracy on training set: 0.999
# Accuracy on test set: 0.997

# %% [markdown]
# #### Test on Thomas datasets

# %%
gt = pd.read_csv("../../dumps/thomas_datasets/2019-08.Merged_thomas.csv")
cols = [col for col in gt.columns if col not in ['label']]
data = gt[cols]
target = gt['label']

data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.20, random_state = 0)
scaler = Normalizer()
scaler.fit(data_train)
data_train = scaler.transform(data_train)
data_test = scaler.transform(data_test)

tree = MLPClassifier(solver='adam',hidden_layer_sizes=(100, 100, 100),max_iter=10000)
tree.fit(data_train, target_train)
print("Accuracy on training set: {:.3f}".format(tree.score(data_train, target_train))) 
print("Accuracy on test set: {:.3f}".format(tree.score(data_test, target_test)))
# Out:
# Accuracy on training set: 0.975
# Accuracy on test set: 0.971

# %%
gt = pd.read_csv("../../dumps/thomas_datasets/2019-09.Merged_thomas.csv")
cols = [col for col in gt.columns if col not in ['label']]
data = gt[cols]
target = gt['label']

data_train, data_test, target_train, target_test = train_test_split(data,target, test_size = 0.20, random_state = 0)
scaler = Normalizer()
scaler.fit(data_train)
data_train = scaler.transform(data_train)
data_test = scaler.transform(data_test)

tree = MLPClassifier(solver='adam',hidden_layer_sizes=(100, 100, 100),max_iter=10000)
tree.fit(data_train, target_train)
print("Accuracy on training set: {:.3f}".format(tree.score(data_train, target_train))) 
print("Accuracy on test set: {:.3f}".format(tree.score(data_test, target_test)))
# Out:
# Accuracy on training set: 0.993
# Accuracy on test set: 0.987
