# %% [markdown]
# # Principal Component Analysis (PCA)

# %%
# %load_ext autoreload
# %autoreload

# Imports
import sys
sys.path.append("../utils")
from utils import PCA_reduction, PCA_components, PCA_snapshot

# %%
PCA_reduction('../../dumps/various_sizes/16K.csv','gaussian')
# Out:
# Variance      Training acc    Test acc  Components      Time (s)
# ----------  --------------  ----------  ------------  ----------
# no pca            0.597677    0.591334  all            0.0240315
# 1                 0.620596    0.622818  119            0.0403821
# 0.99              0.714141    0.712905  102            0.0347914
# 0.95              0.920175    0.918329  82             0.0297188
# 0.9               0.933583    0.927993  64             0.0394733
# 0.85              0.929373    0.927057  52             0.027663

# %% [markdown]
# Gathering features here crazily improves the accuracies from 62 to 93% in nearly the same time, even faster !

# %%
PCA_reduction('../../dumps/various_sizes/16K.csv','bernoulli')
# Out:
# Variance      Training acc    Test acc  Components      Time (s)
# ----------  --------------  ----------  ------------  ----------
# no pca            0.864203    0.879364  all            0.0218911
# 1                 0.952838    0.950748  119            0.053472
# 0.99              0.944185    0.946696  102            0.0558491
# 0.95              0.944029    0.944202  82             0.0389819
# 0.9               0.950811    0.951372  64             0.034922
# 0.85              0.944808    0.945449  52             0.0402085

# %% [markdown]
# Here feature clustering improves the time but slightly decreases the accuracies.

# %%
PCA_components('../../dumps/various_sizes/16K.csv','gaussian')
# Out:
# Top 5 combinations of features :
#
# # components      Test accuracy    Time (s)    Fixed cost (s)
# --------------  ---------------  ----------  ----------------
# no PCA                 0.591334   0.0224402
# 28                     0.949813   0.0159705         0.0997465
# 32                     0.949813   0.0147148         0.109112
# 21                     0.948254   0.0133542         0.08203
# 23                     0.948254   0.0154065         0.0871578
# 33                     0.948254   0.0166159         0.112126
# 28

# %%
PCA_components('../../dumps/various_sizes/16K.csv','bernoulli')
# Out:
# Top 5 combinations of features :
#
# # components      Test accuracy    Time (s)    Fixed cost (s)
# --------------  ---------------  ----------  ----------------
# no PCA                 0.879364   0.0303206
# 19                     0.948254   0.0235989          0.102741
# 18                     0.94389    0.0193468          0.120267
# 28                     0.942955   0.0226753          0.134784
# 22                     0.942332   0.0190296          0.107538
# 26                     0.94202    0.0210892          0.115538
# 19

# %%
PCA_snapshot('../../dumps/time_analysis/threshold_3/3_20190615_31000.csv','gaussian','../')

# %%
PCA_snapshot('../../dumps/time_analysis/threshold_3/3_20190615_31000.csv','bernoulli','../')
# Out:
# Top 5 combinations of features :
#
# # components      Test accuracy    Time (s)    Fixed cost (s)
# --------------  ---------------  ----------  ----------------
# no PCA                 0.845968   0.0431775
# 18                     0.925645   0.0315039          0.178553
# 22                     0.925484   0.0393259          0.216157
# 20                     0.925161   0.0324676          0.215019
# 21                     0.925      0.0381694          0.211671
# 27                     0.921935   0.0398845          0.244952
# Accuracy on training set: 0.923
# Accuracy on test set: 0.673
