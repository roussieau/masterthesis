# %%
# %load_ext autoreload
# %autoreload

import sys
sys.path.append('../../utils')
from utils import PCA_reduction, PCA_components, PCA_snapshot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### PCA

# %%
PCA_reduction('../../../dumps/various_sizes/16K.csv','log')
# Out:
# Variance      Training acc    Test acc  Components      Time (s)
# ----------  --------------  ----------  ------------  ----------
# no pca            0.898425    0.899002  all             0.20784
# 1                 0.992438    0.991895  119             1.24506
# 0.99              0.991737    0.990337  102             1.19518
# 0.95              0.988697    0.985661  82              0.998307
# 0.9               0.987449    0.984726  64              0.497787
# 0.85              0.986982    0.984726  52              0.639029

# %% [markdown]
# Interesting to notice that in the case of the LogReg, accuracies are reduced but we save quite a lot of time (around twice faster for a loss of 0.6% precision).

# %%
PCA_components('../../../dumps/various_sizes/16K.csv','log')
# Out:
# Top 5 combinations of features :
#
# # components      Test accuracy    Time (s)    Fixed cost (s)
# --------------  ---------------  ----------  ----------------
# no PCA                 0.899002    0.320694
# 34                     0.981297    0.152948          0.136382
# 40                     0.980985    0.30423           0.156513
# 38                     0.980362    0.240114          0.190043
# 35                     0.97818     0.161568          0.146753
# 37                     0.977556    0.226911          0.142315
# 34

# %%
PCA_snapshot('../../../dumps/time_analysis/threshold_3/3_20190615_31000.csv','log','../../')
# Out:
# Top 5 combinations of features :
#
# # components      Test accuracy    Time (s)    Fixed cost (s)
# --------------  ---------------  ----------  ----------------
# no PCA                 0.889032    0.424823
# 32                     0.964355    0.306385          0.233301
# 29                     0.962419    0.227229          0.287717
# 34                     0.96129     0.325163          0.243665
# 36                     0.959516    0.346885          0.267936
# 31                     0.958871    0.330643          0.226158
# Accuracy on training set: 0.882
# Accuracy on test set: 0.894
