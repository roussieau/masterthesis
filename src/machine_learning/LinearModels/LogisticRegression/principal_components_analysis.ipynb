# %%
# %load_ext autoreload
# %autoreload

import sys
sys.path.append('../../utils')
from utils import PCA_reduction, PCA_components, PCA_snapshot

# %% [markdown]
# ### PCA

# %%
PCA_reduction('../../../dumps/various_sizes/16K.csv','log')
# Out:
# Variance      Training acc    Test acc  Components      Time (s)
# ----------  --------------  ----------  ------------  ----------
# no pca            0.991971    0.990648  all             0.373997
# 1                 0.991971    0.990648  119             0.419801
# 0.99              0.991035    0.98909   102             0.34844
# 0.95              0.987839    0.986284  82              0.360862
# 0.9               0.98706     0.984102  64              0.30881
# 0.85              0.985423    0.983479  52              0.257143

# %% [markdown]
# Interesting to notice that in the case of the LogReg, accuracies are reduced but we save quite a lot of time (around twice faster for a loss of 0.6% precision).

# %%
PCA_components('../../../dumps/various_sizes/16K.csv','log')
# Out:
# Top 5 combinations of features :
#
# # components      Test accuracy    Time (s)    Fixed cost (s)
# --------------  ---------------  ----------  ----------------
# no PCA                 0.990648    0.390699
# 109                    0.99096     0.376064          0.117076
# 110                    0.99096     0.389714          0.116369
# 112                    0.99096     0.347472          0.119511
# 115                    0.990648    0.384294          0.11785
# 116                    0.990648    0.38075           0.123969
# 109

# %%
PCA_snapshot('../../../dumps/time_analysis/threshold_3/3_20190615_31000.csv','log','../../')
# Out:
# Top 5 combinations of features :
#
# # components      Test accuracy    Time (s)    Fixed cost (s)
# --------------  ---------------  ----------  ----------------
# no PCA                 0.982097    0.909258
# 116                    0.982097    0.904531          0.230633
# 117                    0.982097    0.874622          0.231149
# 102                    0.980484    0.801994          0.235835
# 103                    0.980484    0.885512          0.227065
# 88                     0.979677    0.80152           0.596291
# Accuracy on training set: 0.882
# Accuracy on test set: 0.894
