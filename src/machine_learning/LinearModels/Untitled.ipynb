# %%
from ... import utils
show_coucou()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-ddd967fe5c75> in <module>
# ----> 1 from ... import utils
#       2 show_coucou()
#
# ValueError: attempted relative import beyond top-level package
